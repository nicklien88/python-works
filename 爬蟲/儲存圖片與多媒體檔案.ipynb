# %%
import requests
import urllib.request
from bs4 import BeautifulSoup
import time
import json
import re
import os

def parse(dom):
    soup = BeautifulSoup(dom, "html.parser")
    img_urls = []
    links = soup.find(id="main-content").find_all("a")
    for link in links:
        if re.match(r"^https?://(i.)?(m.)?imgur.com", link["href"]):
            img_urls.append(link["href"])
    return img_urls


def save(img_urls, title): # img_urls = 網頁中所有圖片的網址的串列, title=文章的標題
    if img_urls:
        try:
            dname = title.strip() #去除字串前後的空白
            os.makedirs(dname)
            for img_url in img_urls:
                if img_url.split("//")[1].startswith("m."):
                    img_url = img_url.replace("//m.", "//i.")
                if not img_url.split("//")[1].startswith("i."):
                    img_url = img_url.split("//")[0] + "//i." + img_url.split("//")[1]
                if not img_url.endswith(".jpg"):
                    img_url += ".jpg"
                fname = img_url.split("/")[-1]
                urllib.request.urlretrieve(img_url, os.path.join(dname, fname))
        except Exception as e:
            print(e)

# %%
def get_web_page(url):
    resp = requests.get(
        url=url, cookies={'over18':'1'}
    )
    if resp.status_code != 200:
        print('Invalid url:',resp.url)
        return None
    else:
        return resp.text
    
def get_articles(dom, date):
    soup = BeautifulSoup(dom, 'html5lib')
    page_div = soup.find('div','btn-group btn-group-paging')
    prev_url = page_div.find_all('a')[1]['href']
    
    articles = []
    divs = soup.find_all('div', 'r-ent')
    for d in divs:
        if d.find('div', 'date').text.strip() == date:
            # 取的貼文數
            push_count = 0
            push_str = d.find('div', 'nrec').text
            if push_str:
                try:
                    push_count = int(push_str)   # 轉換字串為數字
                except ValueError:
                    # 轉換失敗，可能是'爆'或 'X1', 'X2',...
                    #若不是，不做任何事，push_count 保持為 0
                    if push_str == '爆':
                        push_count = 99
                    elif push_str.startswith('X'):
                        push_count = -10
            # 取得文章連結與標題
            if d.find('a'):
                href = d.find('a')['href']
                title = d.find('a').text
                author = d.find('div', 'author').text if d.find('div', 'author') else ''
                articles.append({
                    'title':title,
                    'href':href,
                    'push_count':push_count,
                    'author':author

                })
            
    return articles, prev_url

# %%
PTT_URL = 'https://www.ptt.cc'
current_page = get_web_page(PTT_URL + '/bbs/Beauty/index.html')
if current_page:
    articles = [] # 全部的今日文章
    
    # 今天日期, 去掉開頭的 '0' 以符合PTT網站格式
    today = time.strftime("%m/%d").lstrip('0')
    
    # 目前頁面的今日文章
    current_articles, prev_url = get_articles(current_page, "1/10")
    
    # 若目前頁面有今日文章則加入articles,並回到上一頁繼續尋找是否有今日文章
    while current_articles:
        articles += current_articles
        current_page = get_web_page(PTT_URL + prev_url)
        current_articles, prev_url = get_articles(current_page, "1/10")
    
    # 儲存或處理文章資訊
    print('今日PTT Beauty版有', len(articles), '篇文章')
    count = 0
    for a in articles:
        print(count, a)
        article_page = get_web_page(PTT_URL + a["href"])
        if article_page:
            print("剖析文章中圖片...")
            img_urls = parse(article_page)
            print("剖析完畢")
            print(img_urls)
            save(img_urls, a["title"])
            print("下載圖片")
            a["num_image"] = len(img_urls)
            print("圖片下載完畢")
        count += 1
        
    with open('Beauty.json', 'w', encoding='utf-8') as f:
        json.dump(articles, f, indent=2, sort_keys=True, ensure_ascii=False)
# Out:
# 今日PTT Beauty版有 21 篇文章
# 0 {'title': '[神人] 首投族正妹', 'href': '/bbs/Beauty/M.1578663150.A.993.html', 'push_count': 17, 'author': 'james7923'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://i.imgur.com/SRttOFM.jpg', 'https://i.imgur.com/ypHYsI7.jpg', 'https://i.imgur.com/GzfCmHj.jpg']
# 下載圖片
# 圖片下載完畢
# 1 {'title': '[正妹] 小隻馬', 'href': '/bbs/Beauty/M.1578669549.A.B9D.html', 'push_count': 1, 'author': 'ryanworld'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://i.imgur.com/8oe0Rgi.jpg', 'https://i.imgur.com/ylizGkf.jpg', 'https://i.imgur.com/3brelhU.jpg', 'https://i.imgur.com/pWfvmXj.jpg', 'https://i.imgur.com/6jNgk3V.jpg', 'https://i.imgur.com/MrtxRke.jpg', 'https://i.imgur.com/dzJR6Cj.jpg', 'https://i.imgur.com/78ffa43.jpg', 'https://i.imgur.com/u5qVKWq.jpg', 'https://i.imgur.com/bzuCAY9.jpg', 'https://i.imgur.com/00IzD6j.jpg', 'https://i.imgur.com/j4rVeEe.jpg', 'https://i.imgur.com/6GTUzhT.jpg', 'https://i.imgur.com/8WouBAO.jpg', 'https://i.imgur.com/kDZ5R4d.jpg', 'https://i.imgur.com/eNZcaD7.jpg', 'https://i.imgur.com/QBjbNhN.jpg', 'https://i.imgur.com/vJC3yf3.jpg', 'https://i.imgur.com/1ihqVpe.jpg', 'https://i.imgur.com/irooThg.jpg', 'https://i.imgur.com/e5Vliny.jpg', 'https://i.imgur.com/ovpOFj5.jpg']
# 下載圖片
# 圖片下載完畢
# 2 {'title': '[正妹] 小坂菜緒', 'href': '/bbs/Beauty/M.1578669820.A.654.html', 'push_count': 4, 'author': 'nekoten'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://i.imgur.com/rFQLR6x.jpg', 'https://i.imgur.com/QEutES8.jpg', 'https://i.imgur.com/PQpnP3M.jpg']
# 下載圖片
# 圖片下載完畢
# 3 {'title': '[正妹] 推定6才', 'href': '/bbs/Beauty/M.1578669997.A.BAB.html', 'push_count': 0, 'author': 'D600dust'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://imgur.com/NO4zVlw.jpg']
# 下載圖片
# 圖片下載完畢
# 4 {'title': '[正妹] 本來想大聲斥責', 'href': '/bbs/Beauty/M.1578670283.A.D01.html', 'push_count': 7, 'author': 'tim2468x'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://i.imgur.com/TgeLccY.jpg', 'https://i.imgur.com/v2u5HEy.jpg', 'https://i.imgur.com/qtMpSy6.jpg', 'https://i.imgur.com/xSrnLmd.jpg', 'https://i.imgur.com/MdyINue.jpg']
# 下載圖片
# 圖片下載完畢
# 5 {'title': '[正妹] 高雄車展', 'href': '/bbs/Beauty/M.1578670643.A.E29.html', 'push_count': 1, 'author': 'ryanl'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://i.imgur.com/gE2TRAO.jpg', 'https://i.imgur.com/084lMiO.jpg', 'https://i.imgur.com/KgU2ABQ.jpg', 'https://i.imgur.com/BWhRgeV.jpg', 'https://i.imgur.com/8EiIC92.jpg', 'https://i.imgur.com/ZRH1AGw.jpg', 'https://i.imgur.com/msSsEqz.jpg', 'https://i.imgur.com/0iIJ7vb.jpg', 'https://i.imgur.com/7EoiV2d.jpg', 'https://i.imgur.com/dBoDLYg.jpg', 'https://i.imgur.com/o4S4alM.jpg', 'https://i.imgur.com/t6OmHGs.jpg', 'https://i.imgur.com/2O6pjKn.jpg', 'https://i.imgur.com/i9artS9.jpg', 'https://i.imgur.com/2WJFbDL.jpg', 'https://i.imgur.com/fm2Id8j.jpg', 'https://i.imgur.com/jriC3Up.jpg', 'https://i.imgur.com/EbuLIke.jpg', 'https://i.imgur.com/EdPRJfb.jpg', 'https://i.imgur.com/AOzvWhi.jpg', 'https://i.imgur.com/3E6Dm5U.jpg', 'https://i.imgur.com/xOjgqan.jpg', 'https://i.imgur.com/HJ9dcPq.jpg', 'https://i.imgur.com/Xv1GJ9r.jpg', 'https://i.imgur.com/uJb1Cqa.jpg', 'https://i.imgur.com/4QfIRFm.jpg', 'https://i.imgur.com/fSeIWV8.jpg', 'https://i.imgur.com/83TvHxR.jpg', 'https://i.imgur.com/HXbbN1N.jpg', 'https://i.imgur.com/88UTL4c.jpg', 'https://i.imgur.com/i63LL2s.jpg']
# 下載圖片
# 圖片下載完畢
# 6 {'title': '[正妹] 小室さやか', 'href': '/bbs/Beauty/M.1578587477.A.8F6.html', 'push_count': 4, 'author': 'makilaifan'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://i.imgur.com/yYu55uQ.jpg', 'https://i.imgur.com/6dbNgNB.jpg', 'https://i.imgur.com/I72BBv6.jpg', 'https://i.imgur.com/vEZdvcd.jpg', 'https://i.imgur.com/vzT6Y0h.jpg', 'https://i.imgur.com/1A9TEVO.jpg', 'https://i.imgur.com/V3IeWeA.jpg', 'https://i.imgur.com/CMdapoB.jpg', 'https://i.imgur.com/ydYRBEA.jpg', 'https://i.imgur.com/pvMz008.jpg', 'https://i.imgur.com/qKWD9FV.jpg', 'https://i.imgur.com/mOywfWV.jpg', 'https://i.imgur.com/jGeNjn2.jpg', 'https://i.imgur.com/vqdj0Sr.jpg', 'https://i.imgur.com/rwo7Dkh.jpg', 'https://i.imgur.com/Jr25nZn.jpg']
# 下載圖片
# 圖片下載完畢
# 7 {'title': '[正妹] 六年級白婚紗', 'href': '/bbs/Beauty/M.1578590110.A.E9A.html', 'push_count': 38, 'author': 'ReiKuromiya'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://i.imgur.com/4S7mSl9.jpg', 'https://i.imgur.com/RXYSK4e.jpg', 'https://i.imgur.com/uy5cG2S.jpg', 'https://i.imgur.com/Wua6NJn.jpg', 'https://i.imgur.com/3nfy0Gt.jpg', 'https://i.imgur.com/pPZV6G2.jpg', 'https://i.imgur.com/QOQnUaR.jpg', 'https://i.imgur.com/OeIt07r.jpg', 'https://i.imgur.com/rrvCjKp.jpg', 'https://i.imgur.com/F2Gock9.jpg', 'https://i.imgur.com/ZhZKJQe.jpg', 'https://i.imgur.com/HJNidxm.jpg']
# 下載圖片
# 圖片下載完畢
# 8 {'title': '[正妹] 日本女大生', 'href': '/bbs/Beauty/M.1578601679.A.240.html', 'push_count': 1, 'author': 'huntlin'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://i.imgur.com/FgCoYxY.jpg', 'https://i.imgur.com/JiRrPs8.jpg', 'https://i.imgur.com/NTKXvCk.jpg', 'https://i.imgur.com/bSvSCB1.jpg', 'https://i.imgur.com/93CPjs4.jpg', 'https://i.imgur.com/TSaxARc.jpg', 'https://i.imgur.com/pp0xzOr.jpg', 'https://i.imgur.com/KfVWSwY.jpg', 'https://i.imgur.com/IAzGfTi.jpg', 'https://i.imgur.com/IIjB6mq.jpg', 'https://i.imgur.com/mqcAb3N.jpg', 'https://i.imgur.com/PbChnRM.jpg', 'https://i.imgur.com/dYIwOaR.jpg', 'https://i.imgur.com/APt0lWq.jpg', 'https://i.imgur.com/KoBvYwP.jpg', 'https://i.imgur.com/uzxs12r.jpg', 'https://i.imgur.com/Xbi8J0Z.jpg', 'https://i.imgur.com/iAAV39H.jpg', 'https://i.imgur.com/OV9dca3.jpg']
# 下載圖片
# 圖片下載完畢
# 9 {'title': '[正妹] 我本想大聲斥責....', 'href': '/bbs/Beauty/M.1578615386.A.C45.html', 'push_count': 49, 'author': 'Tapqou'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://imgur.com/ybDCyYs', 'https://imgur.com/a/x3E1Za8', 'https://i.imgur.com/ybDCyYs.mp4', 'https://i.imgur.com/uao6cyL.jpg', 'https://i.imgur.com/H4AOIxd.jpg', 'https://i.imgur.com/hNDNXM9.jpg']
# [Errno 2] No such file or directory: '[正妹] 我本想大聲斥責....\\ybDCyYs.jpg'
# 下載圖片
# 圖片下載完畢
# 10 {'title': '[廣告] AV界韓系小天后 小倉由菜  (圖多)', 'href': '/bbs/Beauty/M.1578619753.A.F0C.html', 'push_count': 9, 'author': 'kelseyaya'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://imgur.com/YWEU9n0.jpg', 'https://imgur.com/rE3HHeK.jpg', 'https://imgur.com/1nIXh2B.jpg', 'https://imgur.com/GQeRHIS.jpg', 'https://imgur.com/Eg3mMPQ.jpg', 'https://imgur.com/H3ipJ8f.jpg', 'https://imgur.com/W8BHTwt.jpg', 'https://imgur.com/Ek6TF0i.jpg', 'https://imgur.com/SeaevpG.jpg', 'https://imgur.com/ap4GUrA.jpg', 'https://imgur.com/Nm4iIx5.jpg', 'https://imgur.com/b6i5lbE.jpg', 'https://imgur.com/cex6kK0.jpg', 'https://imgur.com/XHDhx5T.jpg', 'https://imgur.com/AbFEyS8.jpg', 'https://imgur.com/eWjHh3k.jpg', 'https://imgur.com/veBaNDo.jpg', 'https://imgur.com/Tgph9nI.jpg', 'https://imgur.com/tclCJQI.jpg', 'https://imgur.com/chQc5WY.jpg', 'https://imgur.com/Zct4vvl.jpg', 'https://imgur.com/WBb33Qg.jpg', 'https://imgur.com/1kme9bk.jpg', 'https://imgur.com/XnsILmk.jpg', 'https://imgur.com/y5xQHyv.jpg', 'https://imgur.com/hasx6MJ.jpg', 'https://imgur.com/uk5exCF.jpg', 'https://imgur.com/7mB27JX.jpg', 'https://imgur.com/mgdXCt5.jpg', 'https://imgur.com/YNCq7Wl.jpg', 'https://imgur.com/Jw1d6mq.jpg', 'https://imgur.com/YMRDFOE.jpg', 'https://imgur.com/cdg8woe.jpg', 'https://imgur.com/mFDzt6q.jpg', 'https://imgur.com/hta27GY.jpg', 'https://imgur.com/eNynbMw.jpg', 'https://imgur.com/k71Hify.jpg', 'https://imgur.com/xb34uv6.jpg', 'https://imgur.com/eq2bxzl.jpg', 'https://imgur.com/uAHSZzc.jpg', 'https://imgur.com/8NsWHAf.jpg', 'https://imgur.com/5bsA6rv.jpg', 'https://imgur.com/1eb5xvy.jpg', 'https://imgur.com/k7tLNE7.jpg', 'https://imgur.com/vH3Pu7N.jpg', 'https://imgur.com/Tok240F.jpg', 'https://imgur.com/sknJ4oy.jpg', 'https://imgur.com/C2HCRlD.jpg', 'https://imgur.com/bWq0Ozp.jpg', 'https://imgur.com/GkiW4pS.jpg']
# 下載圖片
# 圖片下載完畢
# 11 {'title': '[正妹] 新垣結衣', 'href': '/bbs/Beauty/M.1578626247.A.30A.html', 'push_count': 99, 'author': 'satomigakki'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://imgur.com/kGQ5rrW.jpg', 'https://imgur.com/LtJ4nB9.jpg', 'https://imgur.com/pWpU577.jpg', 'https://imgur.com/K7rM2Ik.jpg', 'https://imgur.com/dnUQt0Z.jpg', 'https://imgur.com/B5KLRTq.jpg', 'https://imgur.com/PZMYDq6.jpg', 'https://imgur.com/2vIx8wZ.jpg', 'https://imgur.com/oWpS0jg.jpg', 'https://imgur.com/ipx5vci.jpg', 'https://imgur.com/aEbz3So.jpg', 'https://imgur.com/FWHpOB0.jpg', 'https://imgur.com/HMWNaAo.jpg', 'https://imgur.com/moCliL6.jpg', 'https://imgur.com/kbAnsXi.jpg', 'https://imgur.com/ultP9AM.jpg', 'https://imgur.com/rW8VonT.jpg', 'https://imgur.com/tRVB6Ye.jpg', 'https://imgur.com/GddmTRP.jpg', 'https://imgur.com/v9SDLio.jpg', 'https://imgur.com/EzF1M0W.jpg', 'https://imgur.com/DvaEMjB.gif', 'https://i.imgur.com/9ZvKkFV.jpg', 'https://i.imgur.com/BxhxvNq.jpg', 'https://i.imgur.com/JV0k2Ol.jpg']
# 下載圖片
# 圖片下載完畢
# 12 {'title': '[廣告] 櫻花妹實況主', 'href': '/bbs/Beauty/M.1578629207.A.38C.html', 'push_count': 8, 'author': 'graperson'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://imgur.com/GLcgT6v.jpg', 'https://imgur.com/nulejXS.jpg', 'https://imgur.com/TtUyGJf.jpg', 'https://imgur.com/qX6zMW5.jpg', 'https://imgur.com/18QoB9b.jpg', 'https://imgur.com/9lgrpv4.jpg', 'https://imgur.com/xK4DYDO.jpg', 'https://imgur.com/YsP5wnu.jpg', 'https://imgur.com/bpqokRe.jpg']
# 下載圖片
# 圖片下載完畢
# 13 {'title': '[正妹] 來台學中文順便觀光', 'href': '/bbs/Beauty/M.1578630052.A.D6D.html', 'push_count': 45, 'author': 'panzer1224'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://i.imgur.com/PSyGiKD.jpg', 'https://i.imgur.com/pdQAAyQ.jpg', 'https://i.imgur.com/IOZo0AX.jpg', 'https://i.imgur.com/Sh2hmuO.jpg', 'https://i.imgur.com/Wnqxzkc.jpg', 'https://i.imgur.com/emx86tF.jpg', 'https://i.imgur.com/KjBCzGS.jpg', 'https://i.imgur.com/7sXpWY4.jpg', 'https://i.imgur.com/LQ9gDjh.jpg', 'https://i.imgur.com/EbDlto0.jpg', 'https://i.imgur.com/oSe5ZBQ.jpg', 'https://i.imgur.com/fyXgXva.jpg', 'https://i.imgur.com/Weu4nBe.jpg', 'https://i.imgur.com/myTQali.jpg', 'https://i.imgur.com/4NwGEyY.jpg', 'https://i.imgur.com/ybhUeF2.jpg']
# 下載圖片
# 圖片下載完畢
# 14 {'title': '[正妹] 大大的', 'href': '/bbs/Beauty/M.1578635283.A.08C.html', 'push_count': 33, 'author': 'Boss741108'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://i.imgur.com/gLmyT3d.jpg', 'https://i.imgur.com/2u1F4F3.jpg', 'https://i.imgur.com/CpHXtYr.jpg', 'https://i.imgur.com/ZXQ1MHC.jpg', 'https://i.imgur.com/hqSZW9s.gif', 'https://i.imgur.com/ZFVgsuw.gif', 'https://i.imgur.com/hkqqaPS.gif', 'https://i.imgur.com/MCiOCOS.jpg', 'https://i.imgur.com/G7t9Dlg.jpg', 'https://i.imgur.com/FwOpDns.gif', 'https://i.imgur.com/E9GZzGT.gif', 'https://i.imgur.com/YRMwMf0.jpg', 'https://i.imgur.com/6D5bb8s.jpg', 'https://i.imgur.com/0HU9pvX.jpg', 'https://i.imgur.com/YpvA4ET.jpg', 'https://i.imgur.com/qcXVxql.jpg', 'https://i.imgur.com/Pjgg4Pt.jpg', 'https://i.imgur.com/nsVeMwz.jpg', 'https://i.imgur.com/HXjA8WD.jpg']
# 下載圖片
# 圖片下載完畢
# 15 {'title': '[正妹] 抱緊', 'href': '/bbs/Beauty/M.1578643656.A.B60.html', 'push_count': 4, 'author': 'ReiKuromiya'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://i.imgur.com/2CIXXj1.jpg', 'https://i.imgur.com/OLEDYGG.jpg', 'https://i.imgur.com/oGXGxOl.jpg', 'https://i.imgur.com/T8rW4Wn.jpg', 'https://i.imgur.com/LIjrPtx.jpg', 'https://i.imgur.com/Ms8Z1lH.jpg', 'https://i.imgur.com/oXUmGZx.jpg', 'https://i.imgur.com/frjKhdq.jpg', 'https://i.imgur.com/9cxcvMM.jpg', 'https://i.imgur.com/X2VnZmb.jpg', 'https://i.imgur.com/HzHuLSd.jpg', 'https://i.imgur.com/OciSLYR.jpg', 'https://i.imgur.com/24ADSqz.jpg', 'https://i.imgur.com/t4q7uoj.jpg', 'https://i.imgur.com/Xnq8SA0.mp4']
# 下載圖片
# 圖片下載完畢
# 16 {'title': '[正妹] 麥當勞女孩', 'href': '/bbs/Beauty/M.1578648966.A.283.html', 'push_count': 3, 'author': 'Arschloch'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://i.imgur.com/AnxJZj7.jpg', 'https://i.imgur.com/Vh7I8pk.jpg', 'https://i.imgur.com/2dfHRny.jpg', 'https://i.imgur.com/8hCrD2u.jpg', 'https://i.imgur.com/2qu2VzP.jpg', 'https://i.imgur.com/WkOsQr8.jpg', 'https://i.imgur.com/uDnpQXm.jpg', 'https://i.imgur.com/OJcmqd8.jpg', 'https://i.imgur.com/9JJ8YNB.jpg', 'https://i.imgur.com/Zpg93hl.jpg', 'https://i.imgur.com/e7fDnlV.jpg', 'https://i.imgur.com/mm3yl0b.jpg', 'https://i.imgur.com/VwxDkoT.jpg', 'https://i.imgur.com/gKyWlgC.jpg', 'https://i.imgur.com/CPvn4BK.jpg', 'https://i.imgur.com/6H54rQj.jpg', 'https://i.imgur.com/oFf0oc7.jpg', 'https://i.imgur.com/qp05N1H.jpg', 'https://i.imgur.com/XKrfCpI.jpg', 'https://i.imgur.com/u07aMNd.jpg', 'https://i.imgur.com/gHxXgB0.jpg']
# 下載圖片
# 圖片下載完畢
# 17 {'title': '[正妹] COS明日香的大奶妹', 'href': '/bbs/Beauty/M.1578649453.A.0D8.html', 'push_count': -10, 'author': 'ray001a'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://i.imgur.com/YGJQDwt.jpg', 'https://i.imgur.com/PSmW6Y2.jpg', 'https://i.imgur.com/vnCp9xN.jpg', 'https://i.imgur.com/FJY8AI4.jpg', 'https://i.imgur.com/DD2FDUH.jpg', 'https://i.imgur.com/3Tky1kF.jpg', 'https://i.imgur.com/pUYtP3I.jpg', 'https://i.imgur.com/BNSpTOx.jpg', 'https://i.imgur.com/HYy6a4m.jpg', 'https://i.imgur.com/luBFbHf.jpg', 'https://i.imgur.com/kz5UIib.jpg', 'https://i.imgur.com/0tOxeYU.jpg', 'https://i.imgur.com/8CYyXvT.jpg']
# 下載圖片
# 圖片下載完畢
# 18 {'title': '[正妹] 2019年年間AV女優', 'href': '/bbs/Beauty/M.1578649493.A.3DE.html', 'push_count': 54, 'author': 'ReiKuromiya'}
# 剖析文章中圖片...
# 剖析完畢
# []
# 下載圖片
# 圖片下載完畢
# 19 {'title': '[正妹] 五味未知子', 'href': '/bbs/Beauty/M.1578656408.A.489.html', 'push_count': 0, 'author': 'Epimenides'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://i.imgur.com/hmWj16w.jpg', 'https://i.imgur.com/RJAkhax.jpg', 'https://i.imgur.com/lelMfr7.jpg', 'https://i.imgur.com/KFR4BVF.jpg', 'https://i.imgur.com/GnIL71D.jpg']
# 下載圖片
# 圖片下載完畢
# 20 {'title': '[正妹] Gabby Thomas 美國模特兒 167cm', 'href': '/bbs/Beauty/M.1578657931.A.FCA.html', 'push_count': 11, 'author': 'Aotearoa'}
# 剖析文章中圖片...
# 剖析完畢
# ['https://i.imgur.com/C5fo78S.jpg', 'https://i.imgur.com/icB2fUM.jpg', 'https://i.imgur.com/n5Jed2U.jpg', 'https://i.imgur.com/1Ito7wg.jpg', 'https://i.imgur.com/bIbU7EC.jpg', 'https://i.imgur.com/D8BxlXC.jpg', 'https://i.imgur.com/CGOc70a.jpg', 'https://i.imgur.com/0Uk3XeV.jpg', 'https://i.imgur.com/lJKCLQV.jpg', 'https://i.imgur.com/CZW7yJb.jpg', 'https://i.imgur.com/H0P7XDt.jpg', 'https://i.imgur.com/5QHqS68.jpg', 'https://i.imgur.com/FtiQCPW.jpg', 'https://i.imgur.com/G25GfQj.jpg', 'https://i.imgur.com/8g8Rxj6.jpg']
# 下載圖片
# 圖片下載完畢
