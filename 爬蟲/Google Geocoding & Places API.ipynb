# %%
import googlemaps
from pprint import pprint

API_KEY = "AIzaSyAZ_XpnxLP_-_OdaELwKa92u9X1b7yQEWw"

gmaps = googlemaps.Client(key=API_KEY)
geocoding_result = gmaps.geocode("臺北市")
loc = geocoding_result[0]["geometry"]["location"]
places = gmaps.places_nearby(keyword="拉麵", location=loc, radius=2500)["results"]
print("第一筆資料細節")
p = gmaps.place(place_id=places[0]["place_id"], language='zh-tw') #['result']
pprint(p)
# Out:
# 第一筆資料細節
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': '1樓',
#                                     'short_name': '1樓',
#                                     'types': ['subpremise']},
#                                    {'long_name': '30號',
#                                     'short_name': '30號',
#                                     'types': ['street_number']},
#                                    {'long_name': '松壽路',
#                                     'short_name': '松壽路',
#                                     'types': ['route']},
#                                    {'long_name': '信義區',
#                                     'short_name': '信義區',
#                                     'types': ['administrative_area_level_3',
#                                               'political']},
#                                    {'long_name': '台北市',
#                                     'short_name': '台北市',
# ...
