# %%
import requests
from bs4 import BeautifulSoup
import time
import json

def get_web_page(url):
    resp = requests.get(
        url=url, cookies={'over18':'1'}
    )
    if resp.status_code != 200:
        print('Invalid url:',resp.url)
        return None
    else:
        return resp.text
    
def get_articles(dom, date):
    soup = BeautifulSoup(dom, 'html5lib')
    page_div = soup.find('div','btn-group btn-group-paging')
    prev_url = page_div.find_all('a')[1]['href']
    
    articles = []
    divs = soup.find_all('div', 'r-ent')
    for d in divs:
        if d.find('div', 'date').text.strip() == date:
            # 取的貼文數
            push_count = 0
            push_str = d.find('div', 'nrec').text
            if push_str:
                try:
                    push_count = int(push_str)   # 轉換字串為數字
                except ValueError:
                    # 轉換失敗，可能是'爆'或 'X1', 'X2',...
                    #若不是，不做任何事，push_count 保持為 0
                    if push_str == '爆':
                        push_count = 99
                    elif push_str.startswith('X'):
                        push_count = -10
            # 取得文章連結與標題
            if d.find('a'):
                href = d.find('a')['href']
                title = d.find('a').text
                author = d.find('div', 'author').text if d.find('div', 'author') else ''
                articles.append({
                    'title':title,
                    'href':href,
                    'push_count':push_count,
                    'author':author

                })
            
    return articles, prev_url

# %%
PTT_URL = 'https://www.ptt.cc/'
current_page = get_web_page(PTT_URL + '/bbs/Gossiping/index.html')
if current_page:
    articles = [] # 全部的今日文章
    
    # 今天日期, 去掉開頭的 '0' 以符合PTT網站格式
    today = time.strftime("%m/%d").lstrip('0')
    
    # 目前頁面的今日文章
    current_articles, prev_url = get_articles(current_page, today)
    
    # 若目前頁面有今日文章則加入articles,並回到上一頁繼續尋找是否有今日文章
    while current_articles:
        articles += current_articles
        current_page = get_web_page(PTT_URL + prev_url)
        current_articles, prev_url = get_articles(current_page, today)
    
    # 儲存或處理文章資訊
    print('今日有', len(articles), '篇文章')
    threshold = 50
    print('熱門文章(> %d 推):'% (threshold))
    for a in articles:
        if int(a['push_count']) > threshold:
            print(a)
    with open('gossiping.json', 'w', encoding='utf-8') as f:
        json.dump(articles, f, indent=2, sort_keys=True, ensure_ascii=False)
# Out:
# 今日有 1343 篇文章
# 熱門文章(> 50 推):
# {'title': '[問卦] 有沒有招呼計程車窄裙OL的卦？', 'href': '/bbs/Gossiping/M.1579085739.A.65A.html', 'push_count': 53, 'author': 'Forthelife'}
# {'title': '[問卦] 為什麼鎮瀾宮也開始賣年菜了？', 'href': '/bbs/Gossiping/M.1579084683.A.0E2.html', 'push_count': 88, 'author': 'yahe0526'}
# {'title': '[新聞] 蔡壁如拋組「在野大聯盟」王世堅嗆：', 'href': '/bbs/Gossiping/M.1579084374.A.29F.html', 'push_count': 99, 'author': 'cake10414'}
# {'title': '[新聞] 國民黨中常會翻盤 推舉林榮德擔任代理主', 'href': '/bbs/Gossiping/M.1579083720.A.87D.html', 'push_count': 99, 'author': 'dan310546'}
# {'title': '[新聞] 魯肉飯配乾煎虱目魚\u3000敗選顏寬恒PO照', 'href': '/bbs/Gossiping/M.1579082607.A.2D2.html', 'push_count': 71, 'author': 'obelisk0114'}
# {'title': '[問卦] 看到一個小孩在好事多一直哭要幫嗎？', 'href': '/bbs/Gossiping/M.1579081542.A.84F.html', 'push_count': 52, 'author': 'hahaWenZuhah'}
# {'title': 'Re: [新聞] 深耕10年「票投別人」…蕭美琴辦公室主', 'href': '/bbs/Gossiping/M.1579080358.A.675.html', 'push_count': 86, 'author': 'sina1'}
# {'title': '[爆卦] 香港男子從高樓被丟出', 'href': '/bbs/Gossiping/M.1579080740.A.C47.html', 'push_count': 99, 'author': 'eitr2703'}
# {'title': '[問卦] 爆乳蒙面人妻甜蜜色誘 暴力木瓜奶溢出', 'href': '/bbs/Gossiping/M.1579079421.A.2CA.html', 'push_count': 99, 'author': 'tsukiyomi157'}
# {'title': '[新聞] 蔡英文：中國必須正視台灣獨立的事實', 'href': '/bbs/Gossiping/M.1579079899.A.BB5.html', 'push_count': 63, 'author': 'kcbill'}
# {'title': '[爆卦] 遺產20萬p幣樂透(發錢)', 'href': '/bbs/Gossiping/M.1579078336.A.5FB.html', 'push_count': 99, 'author': 'Tosca'}
# {'title': '[問卦] 北海道那些地方一定要去？', 'href': '/bbs/Gossiping/M.1579078548.A.660.html', 'push_count': 78, 'author': 'xzcb2008'}
# {'title': '[新聞] 無名氏再捐新北2000萬元 10年累計1.9億', 'href': '/bbs/Gossiping/M.1579077525.A.D04.html', 'push_count': 63, 'author': 'sthho'}
# {'title': '[新聞] 高雄首例漢他病毒出血熱 呼籲落實防鼠', 'href': '/bbs/Gossiping/M.1579076650.A.583.html', 'push_count': 99, 'author': 'MayBeSoft'}
# {'title': '[新聞] 獨家》參選國民黨主席？周錫瑋三天內決定', 'href': '/bbs/Gossiping/M.1579076239.A.0C9.html', 'push_count': 99, 'author': 'pasionlove'}
# {'title': '[新聞] 控告蔡英文「確認論文不存在」彭文正敗', 'href': '/bbs/Gossiping/M.1579076293.A.B18.html', 'push_count': 68, 'author': 'xianfen'}
# {'title': '[新聞] 吳敦義下台尋改革 親吳中常委：讓60歲以', 'href': '/bbs/Gossiping/M.1579076395.A.F6A.html', 'push_count': 99, 'author': 'alex850613'}
# {'title': '[新聞] 羅文嘉、林飛帆宣告請辭\u3000會協助卓榮泰', 'href': '/bbs/Gossiping/M.1579075592.A.0A1.html', 'push_count': 53, 'author': 'flyer1998'}
# {'title': '[新聞] 快訊！羅文嘉、林飛帆宣告請辭', 'href': '/bbs/Gossiping/M.1579075653.A.236.html', 'push_count': 99, 'author': 'plauge'}
# {'title': '[新聞] 替韓國瑜打101分被網罵翻 藍議員告10人', 'href': '/bbs/Gossiping/M.1579074967.A.6DD.html', 'push_count': 99, 'author': 'sukiya'}
# {'title': '[新聞] 影／蠢男沖天炮插屁股中間 \u3000「夾太緊」', 'href': '/bbs/Gossiping/M.1579075108.A.CCF.html', 'push_count': 83, 'author': 'zxc2331189'}
# {'title': '[新聞] 直擊／一天比一天晚！韓國瑜「收假」回', 'href': '/bbs/Gossiping/M.1579073697.A.EBE.html', 'push_count': 62, 'author': 'Y225'}
# {'title': '[新聞] 告蔡英文「論文不存在」\u3000法官「非法律', 'href': '/bbs/Gossiping/M.1579073856.A.86E.html', 'push_count': 83, 'author': 'staedtler'}
# {'title': '[爆卦] 汪報的國民黨主席電子投票', 'href': '/bbs/Gossiping/M.1579073916.A.C86.html', 'push_count': 95, 'author': 'pshuang'}
# {'title': '[新聞] 「先吃飽才有力氣工作啊」落選後顏寬恒臉', 'href': '/bbs/Gossiping/M.1579072824.A.95B.html', 'push_count': 81, 'author': 'HANASUCIA'}
# {'title': '[新聞] 韓國瑜對小雞始亂終棄？何庭歡氣炸回擊 ', 'href': '/bbs/Gossiping/M.1579072971.A.FB1.html', 'push_count': 99, 'author': 'FastGunMan'}
# {'title': 'Re: [新聞] 邀黃國昌當民眾黨副主席？蔡壁如：我們滿', 'href': '/bbs/Gossiping/M.1579072304.A.2D0.html', 'push_count': 75, 'author': 'NARUTO'}
# {'title': '[新聞] 蔡英文：我們沒有需要宣布獨立 因為已經', 'href': '/bbs/Gossiping/M.1579072488.A.B95.html', 'push_count': 99, 'author': 'peterlin495'}
# {'title': '[新聞] 下午是否赴中常會？選黨主席？ 韓國瑜：', 'href': '/bbs/Gossiping/M.1579071706.A.124.html', 'push_count': 94, 'author': 'pigoilstand'}
# {'title': '[新聞] 韓慘敗藍營忙佈局 林佳新：誰敢叫韓獻頭 ', 'href': '/bbs/Gossiping/M.1579071953.A.CA7.html', 'push_count': 81, 'author': 'AaronEckhar'}
# {'title': '[新聞] 國民黨敗選檢討報告1：網軍帶風向、形象受質疑...「本黨不受', 'href': '/bbs/Gossiping/M.1579071096.A.6BC.html', 'push_count': 99, 'author': 'xamous'}
# {'title': '[新聞] 影／國民黨衝突現場！「青黨行動」青年與', 'href': '/bbs/Gossiping/M.1579071180.A.B71.html', 'push_count': 99, 'author': 'Rostislav'}
# {'title': 'Re: [新聞] 社子島擬劃7.9公頃河川區 地方說明會抗', 'href': '/bbs/Gossiping/M.1579068746.A.F5B.html', 'push_count': 69, 'author': 'deann'}
# {'title': '[爆卦] 國民黨亂成一團啦!!!!!', 'href': '/bbs/Gossiping/M.1579068823.A.074.html', 'push_count': 99, 'author': 'sober716'}
# {'title': '[新聞] 要求王立強謊稱被民進黨收買 「對話截圖', 'href': '/bbs/Gossiping/M.1579067362.A.25E.html', 'push_count': 99, 'author': 'Anddyliu'}
# {'title': '[新聞] 嫌登入慢要求償！男砸200萬玩「天堂M」\u3000', 'href': '/bbs/Gossiping/M.1579067717.A.BC6.html', 'push_count': 59, 'author': 'a98987605'}
# {'title': '[新聞] 新黨不解散了 中國國台辦不避嫌表支持', 'href': '/bbs/Gossiping/M.1579066456.A.600.html', 'push_count': 99, 'author': 'vikk33'}
# {'title': '[新聞] 《反滲透法》今上路\u3000國台辦：不折不扣惡法「台灣人要自救！', 'href': '/bbs/Gossiping/M.1579067052.A.E93.html', 'push_count': 99, 'author': 'ericf129'}
# {'title': '[新聞] 中科院試射增程型雄三命中目標 射程達', 'href': '/bbs/Gossiping/M.1579064987.A.F6C.html', 'push_count': 91, 'author': 'helikon'}
# {'title': '[新聞] 荷蘭賀蔡總統連任：期待與「台灣政府」繼', 'href': '/bbs/Gossiping/M.1579064233.A.AA1.html', 'push_count': 99, 'author': 'uini'}
# {'title': '[新聞] 「不能排除戰爭的可能性」\u3000蔡英文：中1', 'href': '/bbs/Gossiping/M.1579064279.A.01F.html', 'push_count': 99, 'author': 'g526153314'}
# {'title': '[新聞] 柯建銘嗆蔡壁如白目 柯文哲：可以互相學', 'href': '/bbs/Gossiping/M.1579063769.A.8AB.html', 'push_count': 99, 'author': 'taipeixcity'}
# {'title': '[新聞] 韓國瑜面臨罷免危機 蔡英文:尊重高雄市民決定', 'href': '/bbs/Gossiping/M.1579063038.A.76D.html', 'push_count': 99, 'author': 'acebank'}
# {'title': '[問卦] 有沒有充電短褲妹的卦？', 'href': '/bbs/Gossiping/M.1579062313.A.6B6.html', 'push_count': 69, 'author': 'Forthelife'}
# {'title': '[問卦] 台北市大安區這樣一碗牛肉麵賣多少', 'href': '/bbs/Gossiping/M.1579062588.A.23E.html', 'push_count': 57, 'author': 'foty'}
# {'title': '[新聞] BBC專訪蔡英文：我們值得中國尊重 侵台將', 'href': '/bbs/Gossiping/M.1579060874.A.6B2.html', 'push_count': 99, 'author': 'ezafine'}
# {'title': '[新聞] 「我盡力了，可以安息了」 65歲苦苓宣布', 'href': '/bbs/Gossiping/M.1579060148.A.4AF.html', 'push_count': 99, 'author': 'kawazakiz2'}
# {'title': '[新聞] 有限度人傳人首度被證實\u3000疾管署：武漢', 'href': '/bbs/Gossiping/M.1579059356.A.E00.html', 'push_count': 74, 'author': 'yahe0526'}
# {'title': 'Re: [新聞] 拚外交被竟被外交部無視\u3000柯文哲：沒有在', 'href': '/bbs/Gossiping/M.1579059794.A.B28.html', 'push_count': 98, 'author': 'forsakesheep'}
# {'title': '[新聞] 拋與民進黨也可合作！柯P正名「全民大聯', 'href': '/bbs/Gossiping/M.1579058450.A.D1E.html', 'push_count': 99, 'author': 'kivan00'}
# {'title': '[新聞] 國民黨怎麼救？徐巧芯：快把這要命標籤', 'href': '/bbs/Gossiping/M.1579058594.A.57A.html', 'push_count': 92, 'author': 'ak904'}
# {'title': 'Re: [新聞] 拚外交被竟被外交部無視\u3000柯文哲：沒有在', 'href': '/bbs/Gossiping/M.1579058767.A.A0C.html', 'push_count': 99, 'author': 'VXcc'}
# {'title': '[新聞] 罷免韓國瑜讓「中風阿嬤」站起來囉！', 'href': '/bbs/Gossiping/M.1579059050.A.333.html', 'push_count': 99, 'author': 'yulecyan04'}
# {'title': '[新聞] 被要求放棄不分區立委 吳斯懷：我辭國民', 'href': '/bbs/Gossiping/M.1579057672.A.66A.html', 'push_count': 99, 'author': 'zombie5623'}
# {'title': '[新聞] 拚外交竟被外交部無視\u3000柯文哲：沒有在', 'href': '/bbs/Gossiping/M.1579058147.A.B61.html', 'push_count': 99, 'author': 'Wojnarowski'}
# {'title': '[新聞] 蔡英文「八字箴言」\u3000國台辦：台灣前途', 'href': '/bbs/Gossiping/M.1579057337.A.BC5.html', 'push_count': 81, 'author': 'm0ark121'}
# {'title': '[問卦] 1/11之後 大家覺得綠蟑螂有變少嗎？', 'href': '/bbs/Gossiping/M.1579057349.A.836.html', 'push_count': 58, 'author': 'joe10337'}
# {'title': '[新聞] 鼓勵韓國瑜選黨主席 陳柏惟：國民黨倒比', 'href': '/bbs/Gossiping/M.1579056002.A.7A1.html', 'push_count': 99, 'author': 'kent'}
# {'title': '[新聞] 社子島擬劃7.9公頃河川區 地方說明會抗', 'href': '/bbs/Gossiping/M.1579056132.A.1A7.html', 'push_count': 80, 'author': 'suno1996'}
# {'title': '[爆卦] 黃淵夏:反滲透法第一天白狼被約談', 'href': '/bbs/Gossiping/M.1579055386.A.3AE.html', 'push_count': 99, 'author': 'GO19870325'}
# {'title': '[新聞] 蔡總統10：40發表談話 將公布施行「反滲', 'href': '/bbs/Gossiping/M.1579055469.A.CA2.html', 'push_count': 99, 'author': 'Gaffky'}
# {'title': '[新聞] 「沒人愛的男人才會支持柯文哲」小學生', 'href': '/bbs/Gossiping/M.1579054753.A.85B.html', 'push_count': 99, 'author': 'RRADA'}
# {'title': '[問卦] 會覺得政論節目不錯看，我是不是老了？', 'href': '/bbs/Gossiping/M.1579054479.A.FD0.html', 'push_count': 84, 'author': 'a3831038'}
# {'title': '[問卦] 「可憐哪」翻譯成英文要怎麼翻譯呢？', 'href': '/bbs/Gossiping/M.1579053234.A.23C.html', 'push_count': 99, 'author': 'qazxc1156892'}
# {'title': '[新聞] 上海解除布拉格姊妹市 柯文哲：中國無權', 'href': '/bbs/Gossiping/M.1579053555.A.280.html', 'push_count': 99, 'author': 'OmegaWind'}
# {'title': '[新聞] 國民黨救亡圖存 徐巧芯：該學民進黨進化！', 'href': '/bbs/Gossiping/M.1579052243.A.F96.html', 'push_count': 57, 'author': 'inglee'}
# {'title': '[新聞] 嫩模Yumi雪乳擺桌照...網諷「可悲台女」遭告神逆轉！', 'href': '/bbs/Gossiping/M.1579051900.A.679.html', 'push_count': 99, 'author': 'kenny1300175'}
# {'title': '[新聞] 蔡總統︰願與中國對話 但台灣主權無談判', 'href': '/bbs/Gossiping/M.1579048669.A.27D.html', 'push_count': 99, 'author': 'leafshot'}
# {'title': 'Re: [問卦] 柯粉變多了嗎？', 'href': '/bbs/Gossiping/M.1579047609.A.D71.html', 'push_count': 76, 'author': 'processior'}
# {'title': '[新聞] 民眾黨想插旗? 林智堅：竹市我顧得很好', 'href': '/bbs/Gossiping/M.1579046100.A.8ED.html', 'push_count': 85, 'author': 'shiaubai'}
# {'title': '[新聞] 新影片曝！烏航班機先後遭伊朗「兩枚飛', 'href': '/bbs/Gossiping/M.1579046596.A.79F.html', 'push_count': 99, 'author': 'STAV72'}
# {'title': 'Re: [爆卦] 外交部小編改文且回應啦', 'href': '/bbs/Gossiping/M.1579040325.A.219.html', 'push_count': 99, 'author': 'newwu'}
# {'title': 'Re: [新聞] 改革被喊爛！ 年輕國民黨員發起「青黨」', 'href': '/bbs/Gossiping/M.1579036840.A.3FF.html', 'push_count': 99, 'author': 'Fujiwarano'}
# {'title': 'Re: [討論] 劉仕傑臉書:對不起，我看不下去。', 'href': '/bbs/Gossiping/M.1579029670.A.20A.html', 'push_count': 99, 'author': 'kid725'}
# {'title': 'Re: [討論] 劉仕傑臉書:對不起，我看不下去。', 'href': '/bbs/Gossiping/M.1579024990.A.17B.html', 'push_count': 99, 'author': 'cowardlyman'}
# {'title': '[問卦] 柯粉變多了嗎？', 'href': '/bbs/Gossiping/M.1579023042.A.9FB.html', 'push_count': 99, 'author': 'liang691206'}
# {'title': '[爆卦] 外交部小編改文且回應啦', 'href': '/bbs/Gossiping/M.1579023416.A.7AB.html', 'push_count': 79, 'author': 'shadleheart'}
# {'title': 'Re: [討論] 劉仕傑臉書:對不起，我看不下去。', 'href': '/bbs/Gossiping/M.1579023642.A.900.html', 'push_count': 99, 'author': 'diplomaMill'}
# {'title': 'Re: [問卦] 為什麼TPP可以有150萬政黨票的實力', 'href': '/bbs/Gossiping/M.1579021853.A.7CE.html', 'push_count': 99, 'author': 'ubcs'}
# {'title': '[問卦] 高雄某中學的板擦很特別XDXD', 'href': '/bbs/Gossiping/M.1579019728.A.3D8.html', 'push_count': 59, 'author': 'ericisfish'}
# {'title': 'Re: [討論] 劉仕傑臉書:對不起，我看不下去。', 'href': '/bbs/Gossiping/M.1579020207.A.0BA.html', 'push_count': 99, 'author': 'Tohkachan'}
# {'title': 'Re: [問卦] 美國准將很大嗎？ 為何大家這麼驚訝?', 'href': '/bbs/Gossiping/M.1579019166.A.25B.html', 'push_count': 99, 'author': 'derekhsu'}
# {'title': 'Re: [討論] 劉仕傑臉書:對不起，我看不下去。 ', 'href': '/bbs/Gossiping/M.1579018025.A.228.html', 'push_count': 89, 'author': 'kuluma'}
